# %% [markdown]
# **Import the necessary libraries**

# %%
import pandas as pd

# %% [markdown]
# **Create the DataFrame with the following values:**

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %% [markdown]
# **Assign it to a variable called regiment.**

# %%
regiment=pd.DataFrame(raw_data)
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %% [markdown]
# **From each regiment,what is the mean preTestScore ?**

# %%
regiment.groupby('regiment').preTestScore.mean()
# Out:
# regiment
# Dragoons      15.50
# Nighthawks    15.25
# Scouts         2.50
# Name: preTestScore, dtype: float64

# %% [markdown]
# **Present general statistics by company**

# %%
regiment.groupby('company').mean(numeric_only=True)
# Out:
#          preTestScore  postTestScore
# company
# 1st          6.666667      57.666667
# 2nd         15.500000      67.000000

# %% [markdown]
# **What is the mean of each company's preTestScore?**

# %%
regiment.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %% [markdown]
# **Present the mean preTestScores grouped by regiment and company**

# %%
regiment.groupby(['regiment','company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %% [markdown]
# **Present the mean postTestScores grouped by regiment and company**

# %%
regiment.groupby(['regiment','company']).postTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st        47.5
#             2nd        75.5
# Nighthawks  1st        59.5
#             2nd        59.5
# Scouts      1st        66.0
#             2nd        66.0
# Name: postTestScore, dtype: float64

# %% [markdown]
# **Group the entire dataframe by regiment and company**

# %%
regiment.groupby(['regiment','company']).mean(numeric_only=True)
# Out:
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %% [markdown]
# **What is the number of observations in each regiment and company**

# %%
print('No. of unique observations in Regiment : ',len(regiment.regiment.value_counts()))
print('No. of unique observations in company :',len(regiment.company.value_counts()))
# Out:
# No. of unique observations in Regiment :  3
# No. of unique observations in company : 2
